# %%
# %%
# load data
# path

csv_path = "../data/llm/PoliticalDiscussion_with_llm_labels_cleaned_output.csv"

# %%
df_llm = pd.read_csv(csv_path)

print(df_llm.columns)

df_llm.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 df_llm = pd.read_csv(csv_path)
#       3 print(df_llm.columns)
#       5 df_llm.head()
#
# NameError: name 'pd' is not defined
